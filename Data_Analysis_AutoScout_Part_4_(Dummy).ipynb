# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
from re import sub
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df0 = pd.read_csv("final_4.csv")

# %%
df = df0.copy()

# %%
df
# Out:
#                    make_model           make  price body_type   mileage  \
# 0         Mercedes Benz A 160  Mercedes Benz  16950   Compact  120200.0
# 1      Mercedes Benz A 35 AMG  Mercedes Benz  46990   Compact   18995.0
# 2      Mercedes Benz A 45 AMG  Mercedes Benz  16800   Compact  197000.0
# 3         Mercedes Benz C 160  Mercedes Benz   4690   Compact  165000.0
# 4       Mercedes Benz CLA 180  Mercedes Benz  22550   Compact   83339.0
# ...                       ...            ...    ...       ...       ...
# 21590               Volvo S60          Volvo   4999     Sedan  166512.0
# 21591               Volvo S40          Volvo   5499     Sedan  145000.0
# 21592               Volvo C30          Volvo   7300     Sedan   96000.0
# 21593               Volvo S90          Volvo  29900     Sedan   94343.0
# 21594               Volvo S80          Volvo   4440     Sedan  230047.0
#
#          gearbox fuel_type  seller  power  gears drivetrain emission_class  \
# 0         Manual    Diesel  Dealer   75.0    6.0      Front         Euro 6
# 1      Automatic    Benzin  Dealer  225.0    7.0        4WD         Euro 6
# 2      Automatic    Diesel  Dealer  100.0    7.0        4WD         Euro 6
# 3         Manual    Benzin  Dealer   90.0    6.0       Rear          Other
# 4         Manual    Diesel  Dealer   90.0    7.0      Front         Euro 6
# ...          ...       ...     ...    ...    ...        ...            ...
# 21590     Manual    Benzin  Dealer  154.0    5.0      Front          Other
# 21591  Automatic    Benzin  Dealer  125.0    5.0      Front          Other
# 21592     Manual    Diesel  Dealer   84.0    6.0      Front          Other
# 21593  Automatic    Benzin  Dealer  187.0    8.0      Front         Euro 6
# 21594  Automatic    Benzin  Dealer  147.0    6.0      Front          Other
#
#       previous_owner   age engine_size_cat comfort_convenience_cat
# 0        Second Hand   6.0          Medium                standard
# 1         First Hand   2.0          Medium                standard
# 2        Second Hand   7.0          Medium                standard
# 3        Second Hand  17.0          Medium                standard
# 4         First Hand   4.0          Medium                  luxury
# ...              ...   ...             ...                     ...
# 21590    Second Hand  18.0            High                standard
# 21591    Second Hand  18.0            High                standard
# 21592     First Hand  11.0          Medium                standard
# 21593    Second Hand   5.0          Medium                standard
# 21594    Second Hand  20.0            High                standard
#
# [21595 rows x 16 columns]

# %%
df['make_model_encoded'], unique_values = pd.factorize(df['make_model'])

# %%
df.isnull().sum()
# Out:
# make_model                 0
# make                       0
# price                      0
# body_type                  0
# mileage                    0
# gearbox                    0
# fuel_type                  0
# seller                     0
# power                      0
# gears                      0
# drivetrain                 0
# emission_class             0
# previous_owner             0
# age                        0
# engine_size_cat            0
# comfort_convenience_cat    0
# make_model_encoded         0
# dtype: int64

# %%
df
# Out:
#                    make_model           make  price body_type   mileage  \
# 0         Mercedes Benz A 160  Mercedes Benz  16950   Compact  120200.0
# 1      Mercedes Benz A 35 AMG  Mercedes Benz  46990   Compact   18995.0
# 2      Mercedes Benz A 45 AMG  Mercedes Benz  16800   Compact  197000.0
# 3         Mercedes Benz C 160  Mercedes Benz   4690   Compact  165000.0
# 4       Mercedes Benz CLA 180  Mercedes Benz  22550   Compact   83339.0
# ...                       ...            ...    ...       ...       ...
# 21590               Volvo S60          Volvo   4999     Sedan  166512.0
# 21591               Volvo S40          Volvo   5499     Sedan  145000.0
# 21592               Volvo C30          Volvo   7300     Sedan   96000.0
# 21593               Volvo S90          Volvo  29900     Sedan   94343.0
# 21594               Volvo S80          Volvo   4440     Sedan  230047.0
#
#          gearbox fuel_type  seller  power  gears drivetrain emission_class  \
# 0         Manual    Diesel  Dealer   75.0    6.0      Front         Euro 6
# 1      Automatic    Benzin  Dealer  225.0    7.0        4WD         Euro 6
# 2      Automatic    Diesel  Dealer  100.0    7.0        4WD         Euro 6
# 3         Manual    Benzin  Dealer   90.0    6.0       Rear          Other
# 4         Manual    Diesel  Dealer   90.0    7.0      Front         Euro 6
# ...          ...       ...     ...    ...    ...        ...            ...
# 21590     Manual    Benzin  Dealer  154.0    5.0      Front          Other
# 21591  Automatic    Benzin  Dealer  125.0    5.0      Front          Other
# 21592     Manual    Diesel  Dealer   84.0    6.0      Front          Other
# 21593  Automatic    Benzin  Dealer  187.0    8.0      Front         Euro 6
# 21594  Automatic    Benzin  Dealer  147.0    6.0      Front          Other
#
#       previous_owner   age engine_size_cat comfort_convenience_cat  \
# 0        Second Hand   6.0          Medium                standard
# 1         First Hand   2.0          Medium                standard
# 2        Second Hand   7.0          Medium                standard
# 3        Second Hand  17.0          Medium                standard
# 4         First Hand   4.0          Medium                  luxury
# ...              ...   ...             ...                     ...
# 21590    Second Hand  18.0            High                standard
# 21591    Second Hand  18.0            High                standard
# 21592     First Hand  11.0          Medium                standard
# 21593    Second Hand   5.0          Medium                standard
# 21594    Second Hand  20.0            High                standard
#
#        make_model_encoded
# 0                       0
# 1                       1
# 2                       2
# 3                       3
# 4                       4
# ...                   ...
# 21590                 424
# 21591                 425
# 21592                 426
# 21593                 431
# 21594                 423
#
# [21595 rows x 17 columns]

# %%
unique_values
# Out:
# Index(['Mercedes Benz A 160', 'Mercedes Benz A 35 AMG',
#        'Mercedes Benz A 45 AMG', 'Mercedes Benz C 160',
#        'Mercedes Benz CLA 180', 'Mercedes Benz A 220', 'Mercedes Benz A 200',
#        'Mercedes Benz A 250', 'Mercedes Benz A 180', 'Mercedes Benz GLC 220',
#        ...
#        'Volvo XC90', 'Volvo S90', 'Volvo V90 Cross Country', 'Volvo XC40',
#        'Volvo V60 Cross Country', 'Volvo XC70', 'Volvo V90', 'Volvo V50',
#        'Volvo V60', 'Volvo V70'],
#       dtype='object', length=440)

# %%
df[df.make_model=="Mercedes Benz CLA 180"]["make_model_encoded"]
# Out:
# 4       4
# 614     4
# 686     4
# 691     4
# 721     4
# 751     4
# 763     4
# 775     4
# 801     4
# 1074    4
# 1084    4
# 1126    4
# 1156    4
# 1225    4
# 1284    4
# 1294    4
# 1337    4
# 1358    4
# 1359    4
# 1380    4
# 1396    4
# 1430    4
# 1472    4
# 1511    4
# Name: make_model_encoded, dtype: int64

# %%
df.drop("make_model",axis=1 ,inplace=True)

# %%
df_dummy = pd.get_dummies(data = df, drop_first=True)
df_dummy
# Out:
#        price   mileage  power  gears   age  make_model_encoded  make_Fiat  \
# 0      16950  120200.0   75.0    6.0   6.0                   0      False
# 1      46990   18995.0  225.0    7.0   2.0                   1      False
# 2      16800  197000.0  100.0    7.0   7.0                   2      False
# 3       4690  165000.0   90.0    6.0  17.0                   3      False
# 4      22550   83339.0   90.0    7.0   4.0                   4      False
# ...      ...       ...    ...    ...   ...                 ...        ...
# 21590   4999  166512.0  154.0    5.0  18.0                 424      False
# 21591   5499  145000.0  125.0    5.0  18.0                 425      False
# 21592   7300   96000.0   84.0    6.0  11.0                 426      False
# 21593  29900   94343.0  187.0    8.0   5.0                 431      False
# 21594   4440  230047.0  147.0    6.0  20.0                 423      False
#
#        make_Ford  make_Hyundai  make_Mercedes Benz  ...  fuel_type_Other  \
# 0          False         False                True  ...            False
# 1          False         False                True  ...            False
# 2          False         False                True  ...            False
# 3          False         False                True  ...            False
# 4          False         False                True  ...            False
# ...          ...           ...                 ...  ...              ...
# 21590      False         False               False  ...            False
# 21591      False         False               False  ...            False
# 21592      False         False               False  ...            False
# 21593      False         False               False  ...            False
# 21594      False         False               False  ...            False
#
#        seller_Private seller  drivetrain_Front  drivetrain_Rear  \
# 0                      False              True            False
# 1                      False             False            False
# 2                      False             False            False
# 3                      False             False             True
# 4                      False              True            False
# ...                      ...               ...              ...
# 21590                  False              True            False
# 21591                  False              True            False
# 21592                  False              True            False
# 21593                  False              True            False
# 21594                  False              True            False
#
#        emission_class_Other  previous_owner_Second Hand  engine_size_cat_High  \
# 0                     False                        True                 False
# 1                     False                       False                 False
# 2                     False                        True                 False
# 3                      True                        True                 False
# 4                     False                       False                 False
# ...                     ...                         ...                   ...
# 21590                  True                        True                  True
# 21591                  True                        True                  True
# 21592                  True                       False                 False
# 21593                 False                        True                 False
# 21594                  True                        True                  True
#
#        engine_size_cat_Low  engine_size_cat_Medium  \
# 0                    False                    True
# 1                    False                    True
# 2                    False                    True
# 3                    False                    True
# 4                    False                    True
# ...                    ...                     ...
# 21590                False                   False
# 21591                False                   False
# 21592                False                    True
# 21593                False                    True
# 21594                False                   False
#
#        comfort_convenience_cat_standard
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                  True
# 4                                 False
# ...                                 ...
# 21590                              True
# 21591                              True
# 21592                              True
# 21593                              True
# 21594                              True
#
# [21595 rows x 37 columns]

# %%
df_dummy.T
# Out:
#                                      0        1         2         3      \
# price                                16950    46990     16800      4690
# mileage                           120200.0  18995.0  197000.0  165000.0
# power                                 75.0    225.0     100.0      90.0
# gears                                  6.0      7.0       7.0       6.0
# age                                    6.0      2.0       7.0      17.0
# make_model_encoded                       0        1         2         3
# make_Fiat                            False    False     False     False
# make_Ford                            False    False     False     False
# make_Hyundai                         False    False     False     False
# make_Mercedes Benz                    True     True      True      True
# make_Nissan                          False    False     False     False
# make_Opel                            False    False     False     False
# make_Peugeot                         False    False     False     False
# make_Renault                         False    False     False     False
# make_Seat                            False    False     False     False
# make_Skoda                           False    False     False     False
# make_Toyota                          False    False     False     False
# make_Volvo                           False    False     False     False
# body_type_Convertible                False    False     False     False
# body_type_Coupe                      False    False     False     False
# body_type_Off-Road/Pick-up           False    False     False     False
# body_type_Sedan                      False    False     False     False
# body_type_Station wagon              False    False     False     False
# gearbox_Manual                        True    False     False      True
# fuel_type_Diesel                      True    False      True     False
# fuel_type_Electric                   False    False     False     False
# fuel_type_LPG/CNG                    False    False     False     False
# fuel_type_Other                      False    False     False     False
# seller_Private seller                False    False     False     False
# drivetrain_Front                      True    False     False     False
# drivetrain_Rear                      False    False     False      True
# emission_class_Other                 False    False     False      True
# previous_owner_Second Hand            True    False      True      True
# engine_size_cat_High                 False    False     False     False
# engine_size_cat_Low                  False    False     False     False
# engine_size_cat_Medium                True     True      True      True
# comfort_convenience_cat_standard      True     True      True      True
#
#                                     4        5        6        7        8      \
# price                               22550    26900    44999    23900    14200
# mileage                           83339.0  48900.0  56876.0  21854.0  99016.0
# power                                90.0    140.0    225.0    102.0     66.0
# gears                                 7.0      7.0      7.0      7.0      5.0
# age                                   4.0      3.0      3.0      4.0      7.0
# make_model_encoded                      4        5        1        6        0
# make_Fiat                           False    False    False    False    False
# make_Ford                           False    False    False    False    False
# make_Hyundai                        False    False    False    False    False
# make_Mercedes Benz                   True     True     True     True     True
# make_Nissan                         False    False    False    False    False
# make_Opel                           False    False    False    False    False
# make_Peugeot                        False    False    False    False    False
# make_Renault                        False    False    False    False    False
# make_Seat                           False    False    False    False    False
# make_Skoda                          False    False    False    False    False
# make_Toyota                         False    False    False    False    False
# make_Volvo                          False    False    False    False    False
# body_type_Convertible               False    False    False    False    False
# body_type_Coupe                     False    False    False    False    False
# body_type_Off-Road/Pick-up          False    False    False    False    False
# body_type_Sedan                     False    False    False    False    False
# body_type_Station wagon             False    False    False    False    False
# gearbox_Manual                       True    False    False    False     True
# fuel_type_Diesel                     True    False    False     True     True
# fuel_type_Electric                  False    False    False    False    False
# fuel_type_LPG/CNG                   False    False    False    False    False
# fuel_type_Other                     False    False    False    False    False
# seller_Private seller               False    False    False    False    False
# drivetrain_Front                     True     True    False     True     True
# drivetrain_Rear                     False    False    False    False    False
# emission_class_Other                False    False    False    False    False
# previous_owner_Second Hand          False    False    False    False     True
# engine_size_cat_High                False    False    False    False    False
# engine_size_cat_Low                 False    False    False    False    False
# engine_size_cat_Medium               True     True     True     True     True
# comfort_convenience_cat_standard    False     True     True     True     True
#
#                                     9      ...    21585    21586    21587  \
# price                               37999  ...    15800    46500    33500
# mileage                           90000.0  ...  48900.0  14000.0  53000.0
# power                               280.0  ...    180.0    288.0    228.0
# gears                                 7.0  ...      8.0      8.0      8.0
# age                                   6.0  ...      6.0      3.0      3.0
# make_model_encoded                      2  ...      424      431      424
# make_Fiat                           False  ...    False    False    False
# make_Ford                           False  ...    False    False    False
# make_Hyundai                        False  ...    False    False    False
# make_Mercedes Benz                   True  ...    False    False    False
# make_Nissan                         False  ...    False    False    False
# make_Opel                           False  ...    False    False    False
# make_Peugeot                        False  ...    False    False    False
# make_Renault                        False  ...    False    False    False
# make_Seat                           False  ...    False    False    False
# make_Skoda                          False  ...    False    False    False
# make_Toyota                         False  ...    False    False    False
# make_Volvo                          False  ...     True     True     True
# body_type_Convertible               False  ...    False    False    False
# body_type_Coupe                     False  ...    False    False    False
# body_type_Off-Road/Pick-up          False  ...    False    False    False
# body_type_Sedan                     False  ...     True     True     True
# body_type_Station wagon             False  ...    False    False    False
# gearbox_Manual                      False  ...    False    False    False
# fuel_type_Diesel                    False  ...    False     True    False
# fuel_type_Electric                  False  ...    False    False    False
# fuel_type_LPG/CNG                   False  ...    False    False    False
# fuel_type_Other                     False  ...    False    False    False
# seller_Private seller               False  ...     True    False    False
# drivetrain_Front                    False  ...     True    False    False
# drivetrain_Rear                     False  ...    False    False    False
# emission_class_Other                False  ...    False    False    False
# previous_owner_Second Hand           True  ...    False    False    False
# engine_size_cat_High                False  ...    False    False    False
# engine_size_cat_Low                 False  ...    False    False    False
# engine_size_cat_Medium               True  ...     True     True     True
# comfort_convenience_cat_standard     True  ...     True     True    False
#
#                                     21588     21589     21590     21591  \
# price                               38000     13000      4999      5499
# mileage                           44873.0  114000.0  166512.0  145000.0
# power                               228.0      88.0     154.0     125.0
# gears                                 8.0       6.0       5.0       5.0
# age                                   4.0       4.0      18.0      18.0
# make_model_encoded                    431       422       424       425
# make_Fiat                           False     False     False     False
# make_Ford                           False     False     False     False
# make_Hyundai                        False     False     False     False
# make_Mercedes Benz                  False     False     False     False
# make_Nissan                         False     False     False     False
# make_Opel                           False     False     False     False
# make_Peugeot                        False     False     False     False
# make_Renault                        False     False     False     False
# make_Seat                           False     False     False     False
# make_Skoda                          False     False     False     False
# make_Toyota                         False     False     False     False
# make_Volvo                           True      True      True      True
# body_type_Convertible               False     False     False     False
# body_type_Coupe                     False     False     False     False
# body_type_Off-Road/Pick-up          False     False     False     False
# body_type_Sedan                      True      True      True      True
# body_type_Station wagon             False     False     False     False
# gearbox_Manual                      False      True      True     False
# fuel_type_Diesel                    False      True     False     False
# fuel_type_Electric                  False     False     False     False
# fuel_type_LPG/CNG                   False     False     False     False
# fuel_type_Other                     False     False     False     False
# seller_Private seller                True      True     False     False
# drivetrain_Front                    False      True      True      True
# drivetrain_Rear                     False     False     False     False
# emission_class_Other                False     False      True      True
# previous_owner_Second Hand          False     False      True      True
# engine_size_cat_High                False     False      True      True
# engine_size_cat_Low                 False     False     False     False
# engine_size_cat_Medium               True      True     False     False
# comfort_convenience_cat_standard    False      True      True      True
#
#                                     21592    21593     21594
# price                                7300    29900      4440
# mileage                           96000.0  94343.0  230047.0
# power                                84.0    187.0     147.0
# gears                                 6.0      8.0       6.0
# age                                  11.0      5.0      20.0
# make_model_encoded                    426      431       423
# make_Fiat                           False    False     False
# make_Ford                           False    False     False
# make_Hyundai                        False    False     False
# make_Mercedes Benz                  False    False     False
# make_Nissan                         False    False     False
# make_Opel                           False    False     False
# make_Peugeot                        False    False     False
# make_Renault                        False    False     False
# make_Seat                           False    False     False
# make_Skoda                          False    False     False
# make_Toyota                         False    False     False
# make_Volvo                           True     True      True
# body_type_Convertible               False    False     False
# body_type_Coupe                     False    False     False
# body_type_Off-Road/Pick-up          False    False     False
# body_type_Sedan                      True     True      True
# body_type_Station wagon             False    False     False
# gearbox_Manual                       True    False     False
# fuel_type_Diesel                     True    False     False
# fuel_type_Electric                  False    False     False
# fuel_type_LPG/CNG                   False    False     False
# fuel_type_Other                     False    False     False
# seller_Private seller               False    False     False
# drivetrain_Front                     True     True      True
# drivetrain_Rear                     False    False     False
# emission_class_Other                 True    False      True
# previous_owner_Second Hand          False     True      True
# engine_size_cat_High                False    False      True
# engine_size_cat_Low                 False    False     False
# engine_size_cat_Medium               True     True     False
# comfort_convenience_cat_standard     True     True      True
#
# [37 rows x 21595 columns]
